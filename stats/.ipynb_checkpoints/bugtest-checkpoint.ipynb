# %%
import MySQLdb
def conDB(dbName):   
    DATABASE = {"mozilla":"iwe"}
    db = MySQLdb.connect("localhost","root","9182736450",DATABASE[dbName])
    cursor = db.cursor()
    return cursor

cursor = conDB("mozilla")

# %%
sqlTS = """
UNIX_TIMESTAMP(ts1) - UNIX_TIMESTAMP(ts0),
UNIX_TIMESTAMP(ts2) - UNIX_TIMESTAMP(ts1),
UNIX_TIMESTAMP(ts3) - UNIX_TIMESTAMP(ts2),
UNIX_TIMESTAMP(ts4)- UNIX_TIMESTAMP(ts3),
UNIX_TIMESTAMP(ts5)- UNIX_TIMESTAMP(ts4) 
"""
sql = "SELECT transition, " + sqlTS + " FROM iwe_statustran "
cursor.execute(sql)
rawD = cursor.fetchall()

# %%
import numpy as np
import pandas as pd

# %%
import time

# %%
t1 = time.clock()
data = list(rawD)    
# init pandas dataframe
df = pd.DataFrame(data)
t2 = time.clock()
print t2-t1
# Out:
# 0.723257039182

# %%
t1 = time.clock()
gb = df.groupby(df[0])
t2 = time.clock()
print t2-t1
# Out:
# 0.000684218388825

# %%
t1 = time.clock()
s2 = gb.mean().T
t2 = time.clock()
print t2-t1
# Out:
# 0.0408227498053

# %%
t1 = time.clock()
s = gb.quantile([.25,.5,.75]).T
t2 = time.clock()
print t2-t1
# Out:
# 9.13738249975

# %%
s
# Out:
# 0 ASSIGNED NEW                         ASSIGNED NEW ASSIGNED             \
#           0.25        0.50        0.75                  0.25       0.50
# 1    7314989.0  21087081.0  45343355.5             1454132.5  3591521.0
# 2          NaN         NaN         NaN             4435416.5  6616153.0
# 3          NaN         NaN         NaN                   NaN        NaN
# 4          NaN         NaN         NaN                   NaN        NaN
# 5          NaN         NaN         NaN                   NaN        NaN
#
# 0              ASSIGNED NEW ASSIGNED NEW                          \
#           0.75                      0.25        0.50        0.75
# 1  21694197.00                 6442845.0  17948492.0  18860659.0
# 2  14062928.25                 1577623.0   7602607.0   9875705.0
# 3          NaN                   17606.0   6624657.0  37044237.0
# 4          NaN                       NaN         NaN         NaN
# 5          NaN                       NaN         NaN         NaN
#
# 0 ASSIGNED NEW ASSIGNED NEW ASSIGNED     ...       \
#                                 0.25     ...
# 1                          2067637.0     ...
# 2                          4558239.0     ...
# 3                           286385.0     ...
# 4                          1421447.0     ...
# 5                                NaN     ...
#
# 0 UNCONFIRMED RESOLVED VERIFIED UNCONFIRMED RESOLVED UNCONFIRMED  \
#                                                             0.75
# 1                                        16564156.25
# 2                                           24825.50
# 3                                            1023.00
# 4                                             585.50
# 5                                            3090.25
#
# 0 UNCONFIRMED RESOLVED VERIFIED UNCONFIRMED RESOLVED VERIFIED            \
#                                                          0.25      0.50
# 1                                            1264.50             9065.5
# 2                                             804.00            16542.5
# 3                                            8264.75           111098.0
# 4                                              38.75             1104.0
# 5                                            1390.25            34200.0
#
# 0             VERIFIED REOPENED RESOLVED VERIFIED                           \
#          0.75                                0.25        0.50         0.75
# 1   166820.75                         76156504.25  76545326.0  76740284.75
# 2   179873.00                               24.75        73.0       110.75
# 3  5598911.25                               66.50       129.0       175.00
# 4    73891.75                                 NaN         NaN          NaN
# 5  1832249.00                                 NaN         NaN          NaN
#
# 0 VERIFIED UNCONFIRMED RESOLVED VERIFIED
#                                     0.25        0.50         0.75
# 1                            19548028.25  19549636.5  19551244.75
# 2                             2402587.75   2404202.5   2405817.25
# 3                             2201492.00   2201495.0   2201498.00
# 4                                    NaN         NaN          NaN
# 5                                    NaN         NaN          NaN
#
# [5 rows x 1578 columns]

# %%
len(data)
# Out:
# 679387

# %%
data[0]
# Out:
# ('NEW RESOLVED VERIFIED', 21540583L, 6580144L, None, None, None)

# %%
t1 = time.clock()
rawDict = {}
for row in data:
    if row[0] not in rawDict:
        rawDict[row[0]] = [[],[],[],[],[]]
    for i in range(1,6):
        rawDict[row[0]][i-1].append(row[i])
t2 = time.clock()
print t2-t1
# Out:
# 2.66007289207

# %%
t1 = time.clock()
totalNum = len(data)
sizeList = []
for tranStr in rawDict:
    sizeList.append([tranStr,len(rawDict[tranStr][0])])
t2 = time.clock()
print t2-t1
# Out:
# 0.00181545945861

# %%
sizeList
# Out:
# [['UNCONFIRMED NEW RESOLVED UNCONFIRMED', 3],
#  ['ASSIGNED NEW RESOLVED', 218],
#  ['RESOLVED VERIFIED NEW RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED RESOLVED REOPENED NEW', 47],
#  ['NEW RESOLVED VERIFIED REOPENED RESOLVED CLOSED', 1],
#  ['NEW RESOLVED UNCONFIRMED ASSIGNED', 1],
#  ['UNCONFIRMED ASSIGNED NEW RESOLVED', 391],
#  ['UNCONFIRMED NEW UNCONFIRMED NEW ASSIGNED', 1],
#  ['UNCONFIRMED ASSIGNED RESOLVED REOPENED ASSIGNED RESOLVED', 16],
#  ['UNCONFIRMED RESOLVED VERIFIED RESOLVED VERIFIED', 42],
#  ['UNCONFIRMED RESOLVED VERIFIED REOPENED ASSIGNED RESOLVED', 1],
#  ['UNCONFIRMED RESOLVED REOPENED RESOLVED', 203],
#  ['NEW UNCONFIRMED NEW UNCONFIRMED', 3],
#  ['NEW RESOLVED ASSIGNED NEW RESOLVED', 1],
#  ['NEW UNCONFIRMED RESOLVED VERIFIED RESOLVED', 1],
#  ['RESOLVED REOPENED RESOLVED REOPENED RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED ASSIGNED UNCONFIRMED NEW RESOLVED', 5],
#  ['CLOSED REOPENED RESOLVED CLOSED', 1],
#  ['NEW ASSIGNED NEW RESOLVED REOPENED ASSIGNED', 2],
#  ['UNCONFIRMED RESOLVED VERIFIED RESOLVED', 94],
#  ['UNCONFIRMED RESOLVED VERIFIED REOPENED RESOLVED VERIFIED', 4],
#  ['UNCONFIRMED ASSIGNED UNCONFIRMED RESOLVED', 9],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED CLOSED', 19],
#  ['NEW RESOLVED UNCONFIRMED RESOLVED VERIFIED', 36],
#  ['UNCONFIRMED NEW RESOLVED REOPENED RESOLVED CLOSED', 2],
#  ['NEW RESOLVED REOPENED RESOLVED VERIFIED CLOSED', 3],
#  ['UNCONFIRMED ASSIGNED RESOLVED UNCONFIRMED NEW RESOLVED', 7],
#  ['NEW RESOLVED REOPENED ASSIGNED RESOLVED CLOSED', 2],
#  ['NEW RESOLVED VERIFIED UNCONFIRMED RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED RESOLVED REOPENED RESOLVED REOPENED RESOLVED', 13],
#  ['NEW RESOLVED ASSIGNED NEW RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED RESOLVED REOPENED NEW RESOLVED', 21],
#  ['UNCONFIRMED NEW ASSIGNED NEW UNCONFIRMED RESOLVED', 140],
#  ['NEW UNCONFIRMED NEW', 138],
#  ['UNCONFIRMED NEW ASSIGNED UNCONFIRMED NEW', 4],
#  ['CLOSED REOPENED RESOLVED VERIFIED REOPENED RESOLVED', 1],
#  ['UNCONFIRMED RESOLVED REOPENED NEW ASSIGNED', 2],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED NEW RESOLVED REOPENED', 10],
#  ['UNCONFIRMED RESOLVED REOPENED UNCONFIRMED RESOLVED', 10],
#  ['UNCONFIRMED NEW ASSIGNED NEW ASSIGNED NEW', 40],
#  ['NEW ASSIGNED RESOLVED ASSIGNED RESOLVED', 4],
#  ['NEW RESOLVED VERIFIED', 70830],
#  ['VERIFIED UNCONFIRMED RESOLVED VERIFIED', 2],
#  ['NEW RESOLVED ASSIGNED RESOLVED VERIFIED', 19],
#  ['NEW ASSIGNED RESOLVED', 43469],
#  ['NEW RESOLVED VERIFIED REOPENED RESOLVED', 346],
#  ['NEW RESOLVED RESOLVED REOPENED RESOLVED RESOLVED', 1],
#  ['UNCONFIRMED ASSIGNED NEW RESOLVED REOPENED RESOLVED', 22],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED NEW RESOLVED CLOSED', 3],
#  ['NEW RESOLVED CLOSED NEW RESOLVED VERIFIED', 1],
#  ['NEW UNCONFIRMED ASSIGNED', 3],
#  ['ASSIGNED RESOLVED REOPENED RESOLVED VERIFIED RESOLVED', 1],
#  ['NEW UNCONFIRMED NEW UNCONFIRMED RESOLVED', 3],
#  ['NEW ASSIGNED UNCONFIRMED NEW RESOLVED', 5],
#  ['NEW ASSIGNED NEW ASSIGNED RESOLVED REOPENED', 7],
#  ['NEW ASSIGNED RESOLVED UNCONFIRMED RESOLVED REOPENED', 1],
#  ['NEW RESOLVED REOPENED ASSIGNED NEW', 39],
#  ['ASSIGNED RESOLVED VERIFIED REOPENED', 2],
#  ['NEW ASSIGNED RESOLVED REOPENED RESOLVED', 2046],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED REOPENED', 9],
#  ['NEW UNCONFIRMED NEW UNCONFIRMED NEW', 1],
#  ['NEW ASSIGNED RESOLVED VERIFIED REOPENED RESOLVED', 103],
#  ['NEW RESOLVED UNCONFIRMED ASSIGNED RESOLVED', 6],
#  ['UNCONFIRMED ASSIGNED RESOLVED UNCONFIRMED ASSIGNED RESOLVED', 2],
#  ['NEW RESOLVED REOPENED RESOLVED REOPENED ASSIGNED', 4],
#  ['NEW ASSIGNED NEW ASSIGNED UNCONFIRMED NEW', 1],
#  ['UNCONFIRMED NEW RESOLVED VERIFIED REOPENED UNCONFIRMED', 1],
#  ['ASSIGNED RESOLVED REOPENED NEW ASSIGNED', 1],
#  ['NEW RESOLVED ASSIGNED RESOLVED REOPENED RESOLVED', 1],
#  ['UNCONFIRMED RESOLVED REOPENED NEW UNCONFIRMED RESOLVED', 1],
#  ['NEW ASSIGNED NEW RESOLVED VERIFIED', 2658],
#  ['UNCONFIRMED ASSIGNED RESOLVED REOPENED RESOLVED', 133],
#  ['UNCONFIRMED RESOLVED VERIFIED RESOLVED VERIFIED RESOLVED', 1],
#  ['NEW UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED VERIFIED', 1],
#  ['RESOLVED REOPENED RESOLVED', 5],
#  ['NEW RESOLVED VERIFIED REOPENED ASSIGNED RESOLVED', 26],
#  ['NEW RESOLVED REOPENED ASSIGNED', 47],
#  ['ASSIGNED NEW RESOLVED REOPENED ASSIGNED RESOLVED', 1],
#  ['NEW RESOLVED REOPENED UNCONFIRMED', 3],
#  ['NEW RESOLVED REOPENED RESOLVED', 7756],
#  ['UNCONFIRMED RESOLVED VERIFIED ASSIGNED RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED NEW RESOLVED CLOSED', 68],
#  ['UNCONFIRMED NEW RESOLVED REOPENED NEW ASSIGNED', 3],
#  ['UNCONFIRMED RESOLVED CLOSED', 433],
#  ['ASSIGNED RESOLVED CLOSED', 7],
#  ['NEW ASSIGNED NEW ASSIGNED RESOLVED CLOSED', 8],
#  ['ASSIGNED NEW RESOLVED VERIFIED CLOSED', 1],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED REOPENED NEW', 5],
#  ['NEW ASSIGNED UNCONFIRMED NEW RESOLVED VERIFIED', 1],
#  ['NEW RESOLVED REOPENED RESOLVED NEW', 1],
#  ['UNCONFIRMED NEW UNCONFIRMED RESOLVED REOPENED NEW', 18],
#  ['UNCONFIRMED NEW RESOLVED VERIFIED REOPENED NEW', 20],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED NEW RESOLVED VERIFIED', 599],
#  ['UNCONFIRMED ASSIGNED RESOLVED VERIFIED', 1131],
#  ['NEW UNCONFIRMED NEW RESOLVED VERIFIED', 32],
#  ['UNCONFIRMED RESOLVED VERIFIED CLOSED', 205],
#  ['ASSIGNED RESOLVED REOPENED ASSIGNED RESOLVED VERIFIED', 17],
#  ['UNCONFIRMED NEW ASSIGNED NEW RESOLVED VERIFIED', 494],
#  ['UNCONFIRMED ASSIGNED RESOLVED REOPENED RESOLVED VERIFIED', 47],
#  ['NEW RESOLVED REOPENED NEW RESOLVED REOPENED', 9],
#  ['ASSIGNED RESOLVED REOPENED NEW RESOLVED', 6],
#  ['NEW ASSIGNED RESOLVED ASSIGNED RESOLVED VERIFIED', 3],
#  ['UNCONFIRMED NEW ASSIGNED NEW ASSIGNED', 39],
#  ['ASSIGNED NEW RESOLVED VERIFIED REOPENED NEW', 1],
#  ['UNCONFIRMED NEW RESOLVED REOPENED UNCONFIRMED NEW', 2],
#  ['UNCONFIRMED NEW UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED', 3],
#  ['UNCONFIRMED RESOLVED CLOSED UNCONFIRMED RESOLVED', 27],
#  ['NEW RESOLVED VERIFIED REOPENED NEW RESOLVED', 113],
#  ['UNCONFIRMED RESOLVED REOPENED ASSIGNED', 7],
#  ['NEW RESOLVED REOPENED UNCONFIRMED RESOLVED', 37],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED UNCONFIRMED', 39],
#  ['ASSIGNED NEW ASSIGNED RESOLVED REOPENED NEW', 1],
#  ['ASSIGNED NEW ASSIGNED RESOLVED', 105],
#  ['UNCONFIRMED NEW RESOLVED CLOSED REOPENED RESOLVED', 4],
#  ['UNCONFIRMED ASSIGNED RESOLVED REOPENED NEW RESOLVED', 19],
#  ['ASSIGNED RESOLVED REOPENED RESOLVED', 411],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED ASSIGNED NEW RESOLVED', 14],
#  ['ASSIGNED NEW', 226],
#  ['ASSIGNED UNCONFIRMED', 1],
#  ['NEW UNCONFIRMED RESOLVED', 1170],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED NEW ASSIGNED', 18],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED', 664],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED', 7781],
#  ['UNCONFIRMED RESOLVED VERIFIED REOPENED NEW', 3],
#  ['NEW UNCONFIRMED RESOLVED REOPENED ASSIGNED RESOLVED', 1],
#  ['ASSIGNED RESOLVED', 12086],
#  ['NEW ASSIGNED RESOLVED REOPENED NEW ASSIGNED', 6],
#  ['ASSIGNED NEW RESOLVED REOPENED ASSIGNED', 1],
#  ['NEW ASSIGNED RESOLVED UNCONFIRMED', 1],
#  ['NEW UNCONFIRMED RESOLVED REOPENED RESOLVED VERIFIED', 1],
#  ['NEW RESOLVED CLOSED NEW RESOLVED CLOSED', 1],
#  ['NEW ASSIGNED UNCONFIRMED ASSIGNED RESOLVED', 1],
#  ['UNCONFIRMED RESOLVED REOPENED UNCONFIRMED RESOLVED REOPENED', 1],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED VERIFIED UNCONFIRMED', 2],
#  ['NEW UNCONFIRMED RESOLVED REOPENED UNCONFIRMED RESOLVED', 2],
#  ['UNCONFIRMED ASSIGNED NEW ASSIGNED NEW RESOLVED', 9],
#  ['NEW RESOLVED REOPENED NEW UNCONFIRMED RESOLVED', 43],
#  ['UNCONFIRMED NEW UNCONFIRMED ASSIGNED NEW RESOLVED', 2],
#  ['NEW ASSIGNED NEW RESOLVED NEW RESOLVED', 3],
#  ['ASSIGNED RESOLVED REOPENED NEW', 6],
#  ['UNCONFIRMED ASSIGNED NEW RESOLVED REOPENED', 3],
#  ['UNCONFIRMED RESOLVED VERIFIED CLOSED UNCONFIRMED RESOLVED', 4],
#  ['UNCONFIRMED NEW RESOLVED REOPENED NEW', 186],
#  ['UNCONFIRMED RESOLVED RESOLVED', 1],
#  ['NEW RESOLVED REOPENED ASSIGNED RESOLVED VERIFIED', 432],
#  ['NEW ASSIGNED NEW UNCONFIRMED RESOLVED', 266],
#  ['UNCONFIRMED NEW UNCONFIRMED NEW', 77],
#  ['UNCONFIRMED RESOLVED CLOSED UNCONFIRMED NEW RESOLVED', 4],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED ASSIGNED RESOLVED', 1],
#  ['RESOLVED CLOSED REOPENED RESOLVED VERIFIED', 3],
#  ['NEW ASSIGNED NEW ASSIGNED RESOLVED', 1366],
#  ['NEW ASSIGNED NEW ASSIGNED NEW ASSIGNED', 21],
#  ['ASSIGNED RESOLVED VERIFIED REOPENED RESOLVED VERIFIED', 13],
#  ['UNCONFIRMED NEW ASSIGNED NEW UNCONFIRMED', 1],
#  ['UNCONFIRMED NEW UNCONFIRMED RESOLVED', 792],
#  ['UNCONFIRMED RESOLVED VERIFIED UNCONFIRMED NEW ASSIGNED', 1],
#  ['NEW UNCONFIRMED RESOLVED REOPENED NEW', 36],
#  ['UNCONFIRMED NEW RESOLVED VERIFIED', 12710],
#  ['UNCONFIRMED NEW RESOLVED REOPENED ASSIGNED NEW', 16],
#  ['NEW RESOLVED CLOSED RESOLVED', 1],
#  ['NEW RESOLVED REOPENED RESOLVED VERIFIED', 4304],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED VERIFIED', 2476],
#  ['UNCONFIRMED NEW RESOLVED REOPENED RESOLVED UNCONFIRMED', 1],
#  ['ASSIGNED NEW RESOLVED REOPENED RESOLVED', 11],
#  ['UNCONFIRMED NEW ASSIGNED RESOLVED CLOSED', 16],
#  ['UNCONFIRMED RESOLVED REOPENED NEW RESOLVED REOPENED', 1],
#  ['NEW UNCONFIRMED NEW RESOLVED REOPENED RESOLVED', 2],
#  ['NEW ASSIGNED RESOLVED NEW RESOLVED VERIFIED', 19],
#  ['UNCONFIRMED ASSIGNED RESOLVED VERIFIED CLOSED', 3],
#  ['NEW ASSIGNED RESOLVED VERIFIED RESOLVED', 15],
#  ['NEW RESOLVED REOPENED NEW ASSIGNED RESOLVED', 215],
#  ['UNCONFIRMED ASSIGNED NEW', 186],
#  ['NEW UNCONFIRMED ASSIGNED UNCONFIRMED RESOLVED', 1],
#  ['NEW ASSIGNED NEW ASSIGNED', 145],
#  ['NEW RESOLVED REOPENED ASSIGNED NEW ASSIGNED', 2],
#  ['UNCONFIRMED RESOLVED REOPENED RESOLVED REOPENED', 8],
#  ['REOPENED RESOLVED', 2],
#  ['NEW RESOLVED REOPENED RESOLVED REOPENED NEW', 19],
#  ['UNCONFIRMED RESOLVED VERIFIED UNCONFIRMED NEW', 50],
#  ['ASSIGNED RESOLVED REOPENED NEW ASSIGNED RESOLVED', 2],
#  ['UNCONFIRMED NEW RESOLVED UNCONFIRMED NEW RESOLVED', 1],
#  ['ASSIGNED NEW ASSIGNED RESOLVED REOPENED RESOLVED', 4],
#  ['NEW ASSIGNED RESOLVED VERIFIED REOPENED', 15],
#  ['NEW UNCONFIRMED RESOLVED UNCONFIRMED NEW', 35],
#  ['NEW RESOLVED REOPENED RESOLVED UNCONFIRMED', 1],
#  ['UNCONFIRMED RESOLVED ASSIGNED RESOLVED', 4],
#  ['NEW RESOLVED VERIFIED ASSIGNED NEW RESOLVED', 1],
#  ['ASSIGNED RESOLVED REOPENED RESOLVED REOPENED', 4],
#  ['NEW RESOLVED VERIFIED RESOLVED', 54],
#  ['ASSIGNED RESOLVED REOPENED ASSIGNED NEW RESOLVED', 1],
#  ['NEW RESOLVED REOPENED RESOLVED UNCONFIRMED RESOLVED', 2],
#  ['NEW ASSIGNED RESOLVED VERIFIED REOPENED NEW', 11],
#  ['UNCONFIRMED NEW ASSIGNED RESOLVED UNCONFIRMED RESOLVED', 4],
#  ['UNCONFIRMED RESOLVED CLOSED UNCONFIRMED RESOLVED VERIFIED', 116],
#  ['UNCONFIRMED NEW ASSIGNED RESOLVED VERIFIED', 4050],
#  ['UNCONFIRMED NEW ASSIGNED RESOLVED ASSIGNED RESOLVED', 1],
#  ['NEW UNCONFIRMED NEW ASSIGNED NEW', 1],
#  ['NEW RESOLVED VERIFIED RESOLVED REOPENED RESOLVED', 3],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED ASSIGNED RESOLVED VERIFIED', 60],
#  ['UNCONFIRMED ASSIGNED RESOLVED REOPENED NEW', 6],
#  ['NEW ASSIGNED NEW RESOLVED', 3588],
#  ['ASSIGNED RESOLVED UNCONFIRMED NEW RESOLVED', 1],
#  ['NEW RESOLVED VERIFIED REOPENED NEW', 39],
#  ['UNCONFIRMED RESOLVED VERIFIED REOPENED RESOLVED', 8],
#  ['UNCONFIRMED ASSIGNED RESOLVED VERIFIED RESOLVED VERIFIED', 1],
#  ['NEW RESOLVED REOPENED RESOLVED VERIFIED REOPENED', 6],
#  ['NEW RESOLVED VERIFIED NEW RESOLVED CLOSED', 1],
#  ['UNCONFIRMED ASSIGNED RESOLVED ASSIGNED RESOLVED VERIFIED', 1],
#  ['NEW ASSIGNED RESOLVED VERIFIED CLOSED', 17],
#  ['NEW ASSIGNED RESOLVED VERIFIED UNCONFIRMED RESOLVED', 1],
#  ['ASSIGNED RESOLVED VERIFIED REOPENED NEW RESOLVED', 1],
#  ['ASSIGNED RESOLVED REOPENED ASSIGNED RESOLVED', 66],
#  ['NEW RESOLVED REOPENED UNCONFIRMED NEW', 14],
#  ['UNCONFIRMED ASSIGNED NEW UNCONFIRMED RESOLVED', 37],
#  ['ASSIGNED NEW ASSIGNED NEW RESOLVED VERIFIED', 17],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED UNCONFIRMED ASSIGNED', 1],
#  ['NEW ASSIGNED RESOLVED NEW', 1],
#  ['NEW UNCONFIRMED RESOLVED REOPENED NEW RESOLVED', 3],
#  ['UNCONFIRMED NEW UNCONFIRMED RESOLVED UNCONFIRMED NEW', 29],
#  ['UNCONFIRMED NEW UNCONFIRMED', 55],
#  ['NEW RESOLVED REOPENED ASSIGNED RESOLVED REOPENED', 7],
#  ['UNCONFIRMED ASSIGNED RESOLVED UNCONFIRMED RESOLVED VERIFIED', 2],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED NEW ASSIGNED NEW', 31],
#  ['ASSIGNED NEW ASSIGNED', 10],
#  ['UNCONFIRMED RESOLVED REOPENED UNCONFIRMED', 7],
#  ['NEW ASSIGNED NEW RESOLVED VERIFIED CLOSED', 5],
#  ['UNCONFIRMED ASSIGNED UNCONFIRMED RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED RESOLVED NEW RESOLVED', 1],
#  ['UNCONFIRMED NEW RESOLVED REOPENED RESOLVED VERIFIED', 759],
#  ['UNCONFIRMED NEW RESOLVED UNCONFIRMED RESOLVED', 10],
#  ['NEW ASSIGNED RESOLVED VERIFIED', 26603],
#  ['NEW UNCONFIRMED', 107],
#  ['NEW RESOLVED UNCONFIRMED NEW RESOLVED REOPENED', 1],
#  ['ASSIGNED RESOLVED REOPENED', 33],
#  ['NEW RESOLVED REOPENED NEW RESOLVED VERIFIED', 725],
#  ['RESOLVED VERIFIED', 56],
#  ['UNCONFIRMED RESOLVED VERIFIED UNCONFIRMED ASSIGNED', 1],
#  ['UNCONFIRMED NEW RESOLVED UNCONFIRMED ASSIGNED RESOLVED', 1],
#  ['NEW ASSIGNED UNCONFIRMED RESOLVED', 8],
#  ['NEW ASSIGNED NEW UNCONFIRMED NEW', 26],
#  ['ASSIGNED NEW RESOLVED REOPENED', 2],
#  ['NEW RESOLVED REOPENED UNCONFIRMED NEW RESOLVED', 6],
#  ['NEW ASSIGNED RESOLVED UNCONFIRMED ASSIGNED RESOLVED', 1],
#  ['NEW RESOLVED REOPENED NEW RESOLVED CLOSED', 1],
#  ['ASSIGNED NEW ASSIGNED NEW ASSIGNED RESOLVED', 5],
#  ['NEW ASSIGNED RESOLVED VERIFIED RESOLVED VERIFIED', 19],
#  ['ASSIGNED RESOLVED REOPENED RESOLVED VERIFIED REOPENED', 1],
#  ['UNCONFIRMED RESOLVED CLOSED UNCONFIRMED RESOLVED CLOSED', 1],
#  ['UNCONFIRMED NEW ASSIGNED RESOLVED VERIFIED CLOSED', 10],
#  ['NEW RESOLVED CLOSED REOPENED RESOLVED VERIFIED', 34],
#  ['UNCONFIRMED RESOLVED REOPENED RESOLVED UNCONFIRMED', 1],
#  ['RESOLVED UNCONFIRMED ASSIGNED RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED NEW UNCONFIRMED RESOLVED REOPENED RESOLVED', 5],
#  ['UNCONFIRMED NEW RESOLVED VERIFIED REOPENED RESOLVED', 90],
#  ['UNCONFIRMED NEW ASSIGNED RESOLVED REOPENED ASSIGNED', 3],
#  ['NEW RESOLVED REOPENED RESOLVED ASSIGNED RESOLVED', 1],
#  ['UNCONFIRMED ASSIGNED NEW ASSIGNED RESOLVED VERIFIED', 77],
#  ['NEW ASSIGNED NEW ASSIGNED NEW', 218],
#  ['NEW ASSIGNED RESOLVED REOPENED NEW RESOLVED', 208],
#  ['NEW RESOLVED REOPENED RESOLVED REOPENED', 88],
#  ['NEW ASSIGNED RESOLVED CLOSED', 88],
#  ['UNCONFIRMED ASSIGNED RESOLVED CLOSED', 3],
#  ['UNCONFIRMED NEW ASSIGNED RESOLVED VERIFIED RESOLVED', 4],
#  ['NEW ASSIGNED RESOLVED REOPENED RESOLVED CLOSED', 2],
#  ['UNCONFIRMED NEW UNCONFIRMED NEW RESOLVED REOPENED', 2],
#  ['NEW ASSIGNED RESOLVED REOPENED ASSIGNED RESOLVED', 381],
#  ['UNCONFIRMED NEW RESOLVED REOPENED RESOLVED REOPENED', 12],
#  ['NEW ASSIGNED NEW ASSIGNED RESOLVED VERIFIED', 2045],
#  ['UNCONFIRMED NEW UNCONFIRMED NEW ASSIGNED RESOLVED', 11],
#  ['NEW ASSIGNED RESOLVED NEW RESOLVED', 3],
#  ['ASSIGNED RESOLVED REOPENED ASSIGNED', 6],
#  ['NEW UNCONFIRMED RESOLVED VERIFIED', 36],
#  ['NEW UNCONFIRMED NEW ASSIGNED NEW RESOLVED', 1],
#  ['UNCONFIRMED RESOLVED NEW RESOLVED VERIFIED CLOSED', 1],
#  ['UNCONFIRMED NEW RESOLVED REOPENED ASSIGNED', 7],
#  ['NEW ASSIGNED RESOLVED REOPENED', 196],
#  ['NEW RESOLVED VERIFIED NEW RESOLVED VERIFIED', 72],
#  ['ASSIGNED NEW ASSIGNED RESOLVED VERIFIED', 88],
#  ['NEW RESOLVED VERIFIED ASSIGNED RESOLVED', 2],
#  ['ASSIGNED RESOLVED REOPENED ASSIGNED NEW', 5],
#  ['UNCONFIRMED NEW RESOLVED REOPENED UNCONFIRMED RESOLVED', 5],
#  ['RESOLVED UNCONFIRMED NEW RESOLVED VERIFIED', 2],
#  ['NEW ASSIGNED RESOLVED REOPENED UNCONFIRMED NEW', 1],
#  ['NEW RESOLVED CLOSED', 238],
#  ['NEW RESOLVED VERIFIED REOPENED', 43],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED ASSIGNED RESOLVED CLOSED', 1],
#  ['NEW ASSIGNED RESOLVED REOPENED NEW', 114],
#  ['NEW UNCONFIRMED RESOLVED UNCONFIRMED NEW UNCONFIRMED', 1],
#  ['NEW RESOLVED UNCONFIRMED NEW RESOLVED', 14],
#  ['NEW RESOLVED REOPENED ASSIGNED UNCONFIRMED NEW', 1],
#  ['NEW RESOLVED VERIFIED REOPENED ASSIGNED', 2],
#  ['UNCONFIRMED RESOLVED VERIFIED REOPENED NEW ASSIGNED', 1],
#  ['NEW RESOLVED UNCONFIRMED NEW ASSIGNED RESOLVED', 5],
#  ['UNCONFIRMED RESOLVED REOPENED', 252],
#  ['NEW ASSIGNED RESOLVED UNCONFIRMED RESOLVED VERIFIED', 6],
#  ['RESOLVED REOPENED NEW RESOLVED VERIFIED', 2],
#  ['UNCONFIRMED RESOLVED VERIFIED UNCONFIRMED NEW RESOLVED', 120],
#  ['UNCONFIRMED ASSIGNED RESOLVED UNCONFIRMED RESOLVED UNCONFIRMED', 1],
#  ['NEW ASSIGNED RESOLVED ASSIGNED NEW RESOLVED', 2],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED UNCONFIRMED NEW', 55],
#  ['ASSIGNED UNCONFIRMED RESOLVED', 3],
#  ['UNCONFIRMED ASSIGNED RESOLVED UNCONFIRMED RESOLVED', 10],
#  ['UNCONFIRMED RESOLVED NEW RESOLVED VERIFIED', 2],
#  ['NEW RESOLVED VERIFIED REOPENED RESOLVED VERIFIED', 851],
#  ['UNCONFIRMED NEW RESOLVED UNCONFIRMED RESOLVED VERIFIED', 2],
#  ['RESOLVED VERIFIED REOPENED ASSIGNED RESOLVED VERIFIED', 1],
#  ['NEW UNCONFIRMED NEW ASSIGNED', 1],
#  ['NEW RESOLVED CLOSED NEW RESOLVED', 1],
#  ['NEW RESOLVED CLOSED REOPENED RESOLVED CLOSED', 1],
#  ['NEW RESOLVED REOPENED ASSIGNED NEW RESOLVED', 55],
#  ['UNCONFIRMED NEW RESOLVED VERIFIED REOPENED ASSIGNED', 2],
#  ['RESOLVED REOPENED NEW ASSIGNED NEW', 1],
#  ['ASSIGNED NEW RESOLVED REOPENED NEW RESOLVED', 1],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED NEW UNCONFIRMED NEW', 7],
#  ['UNCONFIRMED NEW UNCONFIRMED RESOLVED VERIFIED', 20],
#  ['UNCONFIRMED RESOLVED VERIFIED UNCONFIRMED RESOLVED VERIFIED', 420],
#  ['ASSIGNED RESOLVED REOPENED RESOLVED REOPENED NEW', 1],
#  ['NEW RESOLVED UNCONFIRMED NEW RESOLVED VERIFIED', 5],
#  ['UNCONFIRMED NEW ASSIGNED RESOLVED', 6417],
#  ['UNCONFIRMED NEW UNCONFIRMED RESOLVED UNCONFIRMED', 4],
#  ['NEW ASSIGNED RESOLVED VERIFIED REOPENED ASSIGNED', 1],
#  ['NEW RESOLVED VERIFIED NEW RESOLVED', 1],
#  ['ASSIGNED RESOLVED UNCONFIRMED RESOLVED', 8],
#  ['ASSIGNED UNCONFIRMED RESOLVED VERIFIED', 1],
#  ['ASSIGNED RESOLVED REOPENED RESOLVED VERIFIED', 115],
#  ['UNCONFIRMED NEW ASSIGNED RESOLVED REOPENED RESOLVED', 375],
#  ['NEW ASSIGNED NEW RESOLVED REOPENED UNCONFIRMED', 2],
#  ['UNCONFIRMED RESOLVED VERIFIED REOPENED NEW RESOLVED', 1],
#  ['UNCONFIRMED RESOLVED CLOSED VERIFIED', 4],
#  ['UNCONFIRMED NEW RESOLVED REOPENED ASSIGNED RESOLVED', 105],
#  ['UNCONFIRMED ASSIGNED NEW RESOLVED REOPENED NEW', 4],
#  ['UNCONFIRMED RESOLVED REOPENED ASSIGNED RESOLVED', 26],
#  ['UNCONFIRMED RESOLVED REOPENED NEW RESOLVED VERIFIED', 6],
#  ['NEW ASSIGNED NEW RESOLVED REOPENED NEW', 26],
#  ['ASSIGNED UNCONFIRMED NEW RESOLVED', 2],
#  ['UNCONFIRMED NEW ASSIGNED UNCONFIRMED ASSIGNED', 1],
#  ['UNCONFIRMED ASSIGNED NEW UNCONFIRMED NEW', 5],
#  ['UNCONFIRMED NEW UNCONFIRMED NEW UNCONFIRMED NEW', 8],
#  ['NEW UNCONFIRMED RESOLVED UNCONFIRMED', 2],
#  ['ASSIGNED NEW RESOLVED NEW RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED RESOLVED', 164325],
#  ['UNCONFIRMED NEW ASSIGNED RESOLVED REOPENED NEW', 30],
#  ['UNCONFIRMED ASSIGNED NEW RESOLVED VERIFIED', 111],
#  ['NEW UNCONFIRMED RESOLVED REOPENED', 3],
#  ['NEW ASSIGNED RESOLVED REOPENED RESOLVED VERIFIED', 1554],
#  ['UNCONFIRMED RESOLVED REOPENED UNCONFIRMED NEW', 1],
#  ['UNCONFIRMED RESOLVED VERIFIED UNCONFIRMED RESOLVED CLOSED', 1],
#  ['UNCONFIRMED NEW UNCONFIRMED NEW RESOLVED CLOSED', 2],
#  ['VERIFIED REOPENED RESOLVED VERIFIED', 6],
#  ['NEW RESOLVED CLOSED UNCONFIRMED RESOLVED VERIFIED', 1],
#  ['NEW ASSIGNED RESOLVED CLOSED REOPENED RESOLVED', 3],
#  ['NEW UNCONFIRMED ASSIGNED RESOLVED', 18],
#  ['UNCONFIRMED RESOLVED REOPENED ASSIGNED RESOLVED REOPENED', 1],
#  ['UNCONFIRMED RESOLVED VERIFIED UNCONFIRMED', 26],
#  ['NEW UNCONFIRMED RESOLVED UNCONFIRMED ASSIGNED', 1],
#  ['UNCONFIRMED NEW RESOLVED UNCONFIRMED RESOLVED REOPENED', 1],
#  ['NEW ASSIGNED NEW RESOLVED CLOSED', 6],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED NEW RESOLVED', 1376],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED NEW ASSIGNED RESOLVED', 254],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED REOPENED RESOLVED', 6],
#  ['ASSIGNED NEW RESOLVED REOPENED RESOLVED VERIFIED', 4],
#  ['NEW RESOLVED REOPENED NEW UNCONFIRMED', 2],
#  ['UNCONFIRMED NEW ASSIGNED NEW UNCONFIRMED NEW', 11],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED NEW UNCONFIRMED RESOLVED', 37],
#  ['ASSIGNED NEW ASSIGNED NEW RESOLVED', 14],
#  ['UNCONFIRMED RESOLVED REOPENED ASSIGNED RESOLVED VERIFIED', 9],
#  ['NEW UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED', 4],
#  ['UNCONFIRMED NEW UNCONFIRMED NEW RESOLVED VERIFIED', 7],
#  ['RESOLVED REOPENED RESOLVED VERIFIED', 48],
#  ['NEW RESOLVED VERIFIED UNCONFIRMED RESOLVED', 1],
#  ['NEW RESOLVED REOPENED VERIFIED REOPENED RESOLVED', 1],
#  ['NEW RESOLVED UNCONFIRMED RESOLVED', 107],
#  ['ASSIGNED RESOLVED REOPENED RESOLVED REOPENED RESOLVED', 22],
#  ['UNCONFIRMED RESOLVED VERIFIED UNCONFIRMED ASSIGNED RESOLVED', 8],
#  ['UNCONFIRMED ASSIGNED RESOLVED REOPENED RESOLVED REOPENED', 2],
#  ['NEW RESOLVED REOPENED NEW ASSIGNED NEW', 34],
#  ['UNCONFIRMED RESOLVED REOPENED NEW UNCONFIRMED NEW', 1],
#  ['UNCONFIRMED ASSIGNED RESOLVED NEW RESOLVED VERIFIED', 1],
#  ['NEW RESOLVED REOPENED', 1510],
#  ['RESOLVED REOPENED NEW RESOLVED', 1],
#  ['UNCONFIRMED NEW RESOLVED VERIFIED CLOSED', 47],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED VERIFIED CLOSED', 8],
#  ['NEW ASSIGNED NEW ASSIGNED NEW UNCONFIRMED', 1],
#  ['ASSIGNED NEW ASSIGNED NEW ASSIGNED', 1],
#  ['UNCONFIRMED NEW RESOLVED ASSIGNED RESOLVED VERIFIED', 2],
#  ['ASSIGNED RESOLVED VERIFIED REOPENED RESOLVED', 4],
#  ['NEW RESOLVED VERIFIED RESOLVED VERIFIED', 94],
#  ['NEW ASSIGNED RESOLVED REOPENED RESOLVED REOPENED', 13],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED ASSIGNED NEW', 9],
#  ['UNCONFIRMED RESOLVED REOPENED RESOLVED VERIFIED RESOLVED', 2],
#  ['NEW RESOLVED VERIFIED REOPENED RESOLVED REOPENED', 6],
#  ['NEW UNCONFIRMED RESOLVED REOPENED RESOLVED', 12],
#  ['UNCONFIRMED NEW ASSIGNED UNCONFIRMED ASSIGNED RESOLVED', 1],
#  ['UNCONFIRMED RESOLVED VERIFIED REOPENED', 7],
#  ['NEW RESOLVED REOPENED RESOLVED REOPENED RESOLVED', 783],
#  ['UNCONFIRMED ASSIGNED RESOLVED VERIFIED REOPENED RESOLVED', 13],
#  ['NEW RESOLVED VERIFIED REOPENED UNCONFIRMED RESOLVED', 1],
#  ['ASSIGNED RESOLVED VERIFIED', 1907],
#  ['NEW RESOLVED REOPENED NEW ASSIGNED', 18],
#  ['UNCONFIRMED NEW ASSIGNED NEW', 612],
#  ['UNCONFIRMED ASSIGNED RESOLVED', 3248],
#  ['NEW RESOLVED NEW RESOLVED VERIFIED', 28],
#  ['ASSIGNED RESOLVED VERIFIED RESOLVED', 4],
#  ['ASSIGNED RESOLVED ASSIGNED RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED NEW', 773],
#  ['NEW RESOLVED REOPENED RESOLVED NEW RESOLVED', 1],
#  ['NEW RESOLVED NEW ASSIGNED RESOLVED VERIFIED', 1],
#  ['NEW RESOLVED', 159569],
#  ['NEW ASSIGNED NEW UNCONFIRMED', 3],
#  ['NEW RESOLVED REOPENED RESOLVED CLOSED', 8],
#  ['NEW RESOLVED REOPENED RESOLVED VERIFIED RESOLVED', 7],
#  ['UNCONFIRMED NEW ASSIGNED RESOLVED REOPENED', 23],
#  ['UNCONFIRMED RESOLVED REOPENED NEW ASSIGNED RESOLVED', 12],
#  ['UNCONFIRMED NEW UNCONFIRMED NEW UNCONFIRMED RESOLVED', 1],
#  ['UNCONFIRMED RESOLVED VERIFIED', 53422],
#  ['UNCONFIRMED NEW ASSIGNED RESOLVED VERIFIED REOPENED', 1],
#  ['RESOLVED UNCONFIRMED RESOLVED', 1],
#  ['NEW RESOLVED VERIFIED ASSIGNED RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED RESOLVED REOPENED RESOLVED VERIFIED', 29],
#  ['UNCONFIRMED NEW UNCONFIRMED NEW ASSIGNED NEW', 2],
#  ['UNCONFIRMED NEW UNCONFIRMED NEW RESOLVED', 58],
#  ['NEW ASSIGNED RESOLVED RESOLVED VERIFIED', 1],
#  ['NEW ASSIGNED', 3282],
#  ['NEW ASSIGNED RESOLVED VERIFIED NEW RESOLVED', 1],
#  ['NEW UNCONFIRMED NEW RESOLVED', 98],
#  ['NEW ASSIGNED RESOLVED REOPENED ASSIGNED', 33],
#  ['ASSIGNED RESOLVED REOPENED NEW RESOLVED VERIFIED', 6],
#  ['UNCONFIRMED RESOLVED VERIFIED UNCONFIRMED ASSIGNED NEW', 1],
#  ['RESOLVED VERIFIED REOPENED RESOLVED VERIFIED', 29],
#  ['ASSIGNED NEW ASSIGNED NEW', 9],
#  ['UNCONFIRMED NEW ASSIGNED', 450],
#  ['NEW RESOLVED REOPENED NEW', 443],
#  ['NEW RESOLVED UNCONFIRMED NEW', 8],
#  ['NEW RESOLVED NEW RESOLVED', 14],
#  ['NEW RESOLVED VERIFIED RESOLVED VERIFIED RESOLVED', 1],
#  ['NEW RESOLVED ASSIGNED NEW ASSIGNED RESOLVED', 1],
#  ['RESOLVED VERIFIED UNCONFIRMED RESOLVED VERIFIED', 1],
#  ['NEW UNCONFIRMED NEW UNCONFIRMED ASSIGNED RESOLVED', 1],
#  ['UNCONFIRMED NEW RESOLVED VERIFIED REOPENED', 9],
#  ['NEW RESOLVED NEW', 16],
#  ['UNCONFIRMED NEW UNCONFIRMED RESOLVED REOPENED', 3],
#  ['UNCONFIRMED ASSIGNED NEW UNCONFIRMED RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED NEW UNCONFIRMED ASSIGNED RESOLVED', 2],
#  ['RESOLVED REOPENED NEW ASSIGNED RESOLVED VERIFIED', 5],
#  ['NEW UNCONFIRMED NEW UNCONFIRMED NEW RESOLVED', 1],
#  ['UNCONFIRMED NEW RESOLVED VERIFIED RESOLVED', 10],
#  ['UNCONFIRMED NEW ASSIGNED NEW RESOLVED REOPENED', 6],
#  ['UNCONFIRMED RESOLVED REOPENED RESOLVED UNCONFIRMED RESOLVED', 1],
#  ['UNCONFIRMED NEW ASSIGNED NEW RESOLVED', 1033],
#  ['NEW UNCONFIRMED NEW ASSIGNED RESOLVED', 14],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED ASSIGNED NEW ASSIGNED', 1],
#  ['UNCONFIRMED NEW ASSIGNED NEW RESOLVED CLOSED', 2],
#  ['NEW ASSIGNED RESOLVED UNCONFIRMED NEW RESOLVED', 1],
#  ['UNCONFIRMED NEW RESOLVED REOPENED', 284],
#  ['REOPENED NEW ASSIGNED RESOLVED VERIFIED CLOSED', 1],
#  ['RESOLVED UNCONFIRMED NEW ASSIGNED NEW RESOLVED', 1],
#  ['UNCONFIRMED RESOLVED VERIFIED UNCONFIRMED RESOLVED', 419],
#  ['UNCONFIRMED ASSIGNED NEW ASSIGNED NEW', 13],
#  ['NEW RESOLVED VERIFIED REOPENED ASSIGNED NEW', 4],
#  ['NEW ASSIGNED RESOLVED UNCONFIRMED RESOLVED', 19],
#  ['ASSIGNED RESOLVED VERIFIED RESOLVED VERIFIED', 3],
#  ['UNCONFIRMED NEW UNCONFIRMED ASSIGNED RESOLVED VERIFIED', 3],
#  ['UNCONFIRMED NEW UNCONFIRMED NEW UNCONFIRMED', 1],
#  ['ASSIGNED NEW ASSIGNED NEW ASSIGNED NEW', 1],
#  ['UNCONFIRMED ASSIGNED', 376],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED NEW UNCONFIRMED', 2],
#  ['UNCONFIRMED NEW RESOLVED', 31226],
#  ['UNCONFIRMED ASSIGNED RESOLVED REOPENED ASSIGNED', 1],
#  ['NEW RESOLVED ASSIGNED RESOLVED', 18],
#  ['NEW RESOLVED CLOSED REOPENED RESOLVED', 4],
#  ['NEW ASSIGNED RESOLVED REOPENED VERIFIED', 1],
#  ['NEW ASSIGNED NEW ASSIGNED NEW RESOLVED', 330],
#  ['CLOSED UNCONFIRMED RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED NEW RESOLVED VERIFIED RESOLVED VERIFIED', 13],
#  ['UNCONFIRMED RESOLVED VERIFIED RESOLVED UNCONFIRMED RESOLVED', 2],
#  ['UNCONFIRMED ASSIGNED UNCONFIRMED', 2],
#  ['UNCONFIRMED ASSIGNED RESOLVED VERIFIED RESOLVED', 2],
#  ['NEW ASSIGNED NEW RESOLVED REOPENED', 27],
#  ['NEW ASSIGNED RESOLVED CLOSED VERIFIED', 1],
#  ['UNCONFIRMED RESOLVED VERIFIED UNCONFIRMED RESOLVED UNCONFIRMED', 2],
#  ['NEW RESOLVED RESOLVED VERIFIED', 4],
#  ['NEW ASSIGNED NEW', 2116],
#  ['NEW UNCONFIRMED ASSIGNED RESOLVED REOPENED RESOLVED', 1],
#  ['UNCONFIRMED NEW RESOLVED REOPENED NEW RESOLVED', 405],
#  ['NEW UNCONFIRMED ASSIGNED NEW', 1],
#  ['REOPENED RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED NEW RESOLVED NEW RESOLVED VERIFIED', 2],
#  ['RESOLVED REOPENED ASSIGNED RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED ASSIGNED', 10],
#  ['NEW RESOLVED UNCONFIRMED', 10],
#  ['NEW ASSIGNED NEW UNCONFIRMED NEW RESOLVED', 14],
#  ['NEW UNCONFIRMED ASSIGNED RESOLVED VERIFIED', 6],
#  ['UNCONFIRMED NEW ASSIGNED NEW ASSIGNED RESOLVED', 333],
#  ['CLOSED NEW RESOLVED VERIFIED', 2],
#  ['NEW ASSIGNED RESOLVED REOPENED ASSIGNED NEW', 18],
#  ['UNCONFIRMED NEW', 15249],
#  ['UNCONFIRMED ASSIGNED NEW ASSIGNED', 18],
#  ['RESOLVED UNCONFIRMED NEW ASSIGNED RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED NEW RESOLVED UNCONFIRMED', 1],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED', 485],
#  ['UNCONFIRMED ASSIGNED UNCONFIRMED ASSIGNED RESOLVED VERIFIED', 2],
#  ['NEW UNCONFIRMED RESOLVED UNCONFIRMED NEW RESOLVED', 2],
#  ['NEW RESOLVED REOPENED NEW UNCONFIRMED NEW', 2],
#  ['UNCONFIRMED ASSIGNED RESOLVED REOPENED', 19],
#  ['ASSIGNED NEW RESOLVED VERIFIED', 110],
#  ['NEW RESOLVED REOPENED NEW RESOLVED', 1142],
#  ['UNCONFIRMED ASSIGNED UNCONFIRMED NEW RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED RESOLVED ASSIGNED NEW RESOLVED', 1],
#  ['UNCONFIRMED ASSIGNED UNCONFIRMED ASSIGNED RESOLVED', 1],
#  ['RESOLVED NEW RESOLVED VERIFIED', 3],
#  ['UNCONFIRMED NEW RESOLVED ASSIGNED RESOLVED', 2],
#  ['CLOSED REOPENED RESOLVED VERIFIED', 40],
#  ['UNCONFIRMED ASSIGNED NEW ASSIGNED RESOLVED', 141],
#  ['NEW ASSIGNED NEW RESOLVED RESOLVED VERIFIED', 1],
#  ['UNCONFIRMED NEW RESOLVED REOPENED RESOLVED', 1455],
#  ['REOPENED ASSIGNED NEW ASSIGNED RESOLVED VERIFIED', 2],
#  ['NEW RESOLVED VERIFIED CLOSED', 200],
#  ['NEW RESOLVED UNCONFIRMED RESOLVED REOPENED RESOLVED', 3],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED RESOLVED VERIFIED RESOLVED', 6],
#  ['NEW UNCONFIRMED NEW ASSIGNED RESOLVED VERIFIED', 5],
#  ['NEW ASSIGNED NEW RESOLVED REOPENED RESOLVED', 183],
#  ['NEW ASSIGNED UNCONFIRMED', 6],
#  ['NEW UNCONFIRMED NEW RESOLVED REOPENED', 3],
#  ['NEW RESOLVED REOPENED ASSIGNED RESOLVED', 558],
#  ['UNCONFIRMED NEW RESOLVED UNCONFIRMED NEW', 3],
#  ['UNCONFIRMED RESOLVED UNCONFIRMED ASSIGNED RESOLVED', 103]]

# %%
sizeList =
